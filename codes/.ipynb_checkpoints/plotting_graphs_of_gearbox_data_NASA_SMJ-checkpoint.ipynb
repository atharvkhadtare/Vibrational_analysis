# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os

# %%
training_set_path = os.path.expanduser('~/Vibrational_analysis/data/bearing_fault_nasa_IMS/1st_test')
newheader = ["B1X", "B1Y","B2X", "B2Y","B3X", "B3Y","B4X", "B4Y"]
print (training_set_path)
nof = os.listdir(os.path.expanduser(training_set_path))
RUL = len(nof)
df = pd.read_csv('~/Vibrational_analysis/data/bearingDataNasa/1st_test/2003.10.22.12.06.24',sep="\t",header= None)
df.columns = newheader
# print (RUL)

# print (df)
#     print (df)
#     break
# Out:
# /home/cardioid/Vibrational_analysis/data/bearing_fault_nasa_IMS/1st_test
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-ba29c483f78e> in <module>()
#       2 newheader = ["B1X", "B1Y","B2X", "B2Y","B3X", "B3Y","B4X", "B4Y"]
#       3 print (training_set_path)
# ----> 4 nof = os.listdir(os.path.expanduser(training_set_path))
#       5 RUL = len(nof)
#       6 df = pd.read_csv('~/Vibrational_analysis/data/bearingDataNasa/1st_test/2003.10.22.12.06.24',sep="\t",header= None)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/cardioid/Vibrational_analysis/data/bearing_fault_nasa_IMS/1st_test'

# %%
plt.plot(df.loc[:,"B1X"],'.')
