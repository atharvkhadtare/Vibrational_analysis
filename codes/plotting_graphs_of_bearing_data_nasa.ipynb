# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
def scale_plot_size(factor=3.0):
    default_figsize = mpl.rcParamsDefault['figure.figsize']
    mpl.rcParams['figure.figsize'] = [val*factor for val in default_figsize]
scale_plot_size(1.5)

# %%
training_set_path = os.path.expanduser('~/Vibrational_analysis/data/bearingDataNasa')
header = ["B1X", "B1Y","B2X","B2Y", "B3X","B3Y","B4X","B4Y"]
print (training_set_path)

def normalizeDataFrame(df):
    maxValue = df.max(axis = 0)
#     print (maxValue)
    minValue = df.min(axis = 0)
#     print (minValue)
    diff = maxValue-minValue
#     print (diff)
    mean = df.mean(axis = 0)
#     print(mean)
    ndf = (df-mean)/diff
    return ndf

dirList = os.listdir(os.path.expanduser(training_set_path))
dirList.sort()
n = 0

for sets in dirList:
    print (training_set_path+"/"+sets)
    df = pd.read_csv(training_set_path+"/"+sets,sep = '\t', header=None)
    df.columns = header
#     print (df)
#     normalizedData = normalizeDataFrame(df)
    data = np.array(df,np.float64)
#     print (data)
    coloumn = data[:,6]
#     print (coloumn)
    if n==0 :
        x = coloumn
        n = 1
    else:
        x= np.append(x,coloumn)
    print (x.shape)

#     break
# Out:
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.12.06.24
# (20480,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.12.09.13
# (40960,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.12.14.13
# (61440,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.12.19.13
# (81920,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.12.24.13
# (102400,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.12.29.13
# (122880,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.12.34.13
# (143360,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.12.39.13
# (163840,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.12.44.13
# (184320,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.12.49.13
# (204800,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.12.54.13
# (225280,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.12.59.13
# (245760,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.13.04.13
# (266240,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.13.09.13
# (286720,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.13.14.13
# (307200,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.13.19.13
# (327680,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.13.24.13
# (348160,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.13.29.13
# (368640,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.13.34.13
# (389120,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.13.39.13
# (409600,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.13.44.13
# (430080,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.13.49.13
# (450560,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.13.54.13
# (471040,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.13.59.13
# (491520,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.14.04.13
# (512000,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.14.09.13
# (532480,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.14.14.13
# (552960,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.14.19.13
# (573440,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.14.24.13
# (593920,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.14.29.13
# (614400,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.14.34.13
# (634880,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.14.39.13
# (655360,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.14.44.13
# (675840,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.14.49.13
# (696320,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.14.54.13
# (716800,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.14.59.13
# (737280,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.15.04.13
# (757760,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.15.09.13
# (778240,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.15.14.13
# (798720,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.15.19.13
# (819200,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.15.24.13
# (839680,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.15.29.13
# (860160,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.15.37.48
# (880640,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.15.44.13
# (901120,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.15.54.13
# (921600,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.16.04.13
# (942080,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.16.14.13
# (962560,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.16.24.13
# (983040,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.16.34.13
# (1003520,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.16.44.13
# (1024000,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.16.54.13
# (1044480,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.17.04.13
# (1064960,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22.17.14.13
# (1085440,)
# /home/cardioid/Vibrational_analysis/data/bearingDataNasa/2003.10.22